# %% [markdown]
# # Lab 3 Data Analysis
# David T, Sam D, Dieter B

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from scipy.optimize import curve_fit
import matplotlib.animation as animation
from matplotlib import style

# %%
df = pd.read_csv("robot_run_10_17_19.csv")
df_2d = pd.read_csv("robot_run_corner_stalls_video_10_17_19.csv")

# %%
# drop the extra index column
df = df.drop(['Unnamed: 0'], axis=1)
df_2d = df_2d.drop(['Unnamed: 0'], axis=1)

# %%
df
# Out:
#            t     ml     mr     sl     sr     p    i    d
# 0      66470  25.42  54.58  180.0  344.0  1.75  0.0  0.0
# 1      66476  25.33  54.67  179.0  344.0  1.75  0.0  0.0
# 2      66483  25.51  54.49  180.0  343.0  1.75  0.0  0.0
# 3      66490  25.42  54.58  180.0  344.0  1.75  0.0  0.0
# 4      66496  25.51  54.49  176.0  339.0  1.75  0.0  0.0
# ...      ...    ...    ...    ...    ...   ...  ...  ...
# 9412  131724  70.49   9.51  697.0  354.0  1.75  0.0  0.0
# 9413  131731  66.58  13.42  653.0  354.0  1.75  0.0  0.0
# 9414  131737  58.49  21.51  558.0  350.0  1.75  0.0  0.0
# 9415  131744  51.20  28.80  490.0  364.0  1.75  0.0  0.0
# 9416  131751  41.33  38.67  389.0  374.0  1.75  0.0  0.0
#
# [9417 rows x 8 columns]

# %%
fig = plt.figure(figsize=(8, 8), dpi=300)
interval = 200
ax = fig.add_subplot(111)
c = ax.plot(df["t"][0:interval], df["sl"][0:interval])
d = ax.plot(df["t"][0:interval], df["sr"][0:interval])

ax2 = ax1.twinx()

m1 = ax.plot(df["t"][0:interval], df["ml"][0:interval])
m2 = ax.plot(df["t"][0:interval], df["mr"][0:interval])
ax.set_title("Sensor Readings versus Time")
ax.legend(['Left sensor readings', 'Right sensor readings','Left motor readings','Right motor readings'])
ax.set_xlabel('time (s)')
ax.set_ylabel('Input / Output Value (unitless)')
plt.savefig('one-axis-overlay.png', bbox_inches='tight')
plt.show()

# %%
plt.clf()
# Create some mock data
fig, ax1 = plt.subplots(figsize=(8, 8), dpi=300)

color = 'tab:blue'
color2 = 'tab:orange'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('Sensor Reading', color=color)
ax1.plot(df["t"][0:interval], df["sl"][0:interval], color=color)
ax1.plot(df["t"][0:interval], df["sr"][0:interval], color=color2)
ax1.tick_params(axis='y', labelcolor=color)



ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:cyan'
color2 = 'tab:olive'
ax2.set_ylabel('Motor output', color=color)  # we already handled the x-label with ax1
ax2.plot(df["t"][0:interval], df["ml"][0:interval], color=color)
ax2.plot(df["t"][0:interval], df["mr"][0:interval], color=color2)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.savefig('two-axis-overlay.png', bbox_inches='tight')


plt.show()

# %%
fig = plt.figure(figsize=(8, 8), dpi=300)
interval = 200
color = 'tab:blue'
color2 = 'tab:orange'
ax = fig.add_subplot(211)
c = ax.plot((df["t"][0:interval] - df["t"][0])/ 1000, df["sl"][0:interval], color=color)
d = ax.plot((df["t"][0:interval] - df["t"][0])/ 1000, df["sr"][0:interval], color=color2)

ax.set_title("Line Following Robot Diagnostic Data")
ax.legend(['Left sensor readings', 'Right sensor readings','Left motor readings','Right motor readings'])
ax.set_ylabel('Sensor Analog Reading')
ax.set_xlabel("Time (s)")

color = 'tab:cyan'
color2 = 'tab:olive'
ax2 = fig.add_subplot(212)
m1 = ax2.plot((df["t"][0:interval] - df["t"][0])/ 1000, df["ml"][0:interval], color=color)
m2 = ax2.plot((df["t"][0:interval] - df["t"][0])/ 1000, df["mr"][0:interval], color=color2)
ax2.set_ylabel('Motor Output as Sent')
ax2.set_xlabel("Time (s)")
ax2.legend(['Left motor readings','Right motor readings'])

plt.savefig('subplot-overlay.png', bbox_inches='tight')

plt.show()
